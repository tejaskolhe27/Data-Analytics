# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
car08=pd.read_csv("all_alpha_08.csv")
car18=pd.read_csv("all_alpha_18.csv")

# %%
car08.shape
# Out:
# (2404, 18)

# %%
car18.shape
# Out:
# (1611, 18)

# %%
car08.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# 1  8HNXT03.7PKR          SUV                   6          Drv       15
# 2  8HNXT02.3DKR          SUV                   7          Drv       17
# 3  8HNXT02.3DKR          SUV                   6          Drv       17
# 4  8HNXV03.5HKR  midsize car                   7          Drv       16
#
#   Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
car08.drop(['Underhood ID','Stnd','Sales Area','FE Calc Appr','Unadj Cmb MPG'],
           inplace=True,axis=1)
car08
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel    Veh Class  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          SUV
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          SUV
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          SUV
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          SUV
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline  midsize car
# ...           ...    ...      ...      ...   ...       ...          ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          SUV
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          SUV
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          SUV
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          SUV
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          SUV
#
#      Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score  \
# ...

# %%
car08.duplicated().sum()
# Out:
# 653

# %%
car08.dropna(axis=0,inplace=True)
car08.shape
# Out:
# (2205, 13)

# %%
car08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2205 entries, 0 to 2403
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 2205 non-null   object
#  1   Displ                 2205 non-null   float64
#  2   Cyl                   2205 non-null   object
#  3   Trans                 2205 non-null   object
#  4   Drive                 2205 non-null   object
#  5   Fuel                  2205 non-null   object
#  6   Veh Class             2205 non-null   object
#  7   Air Pollution Score   2205 non-null   object
#  8   City MPG              2205 non-null   object
#  9   Hwy MPG               2205 non-null   object
#  10  Cmb MPG               2205 non-null   object
#  11  Greenhouse Gas Score  2205 non-null   object
#  12  SmartWay              2205 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 241.2+ KB

# %%
car08['Cyl']=pd.to_numeric(car08['Cyl'],errors='ignore')
car08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2205 entries, 0 to 2403
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 2205 non-null   object
#  1   Displ                 2205 non-null   float64
#  2   Cyl                   2205 non-null   object
#  3   Trans                 2205 non-null   object
#  4   Drive                 2205 non-null   object
#  5   Fuel                  2205 non-null   object
#  6   Veh Class             2205 non-null   object
#  7   Air Pollution Score   2205 non-null   object
#  8   City MPG              2205 non-null   object
#  9   Hwy MPG               2205 non-null   object
#  10  Cmb MPG               2205 non-null   object
#  11  Greenhouse Gas Score  2205 non-null   object
#  12  SmartWay              2205 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 241.2+ KB

# %%
car08.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel    Veh Class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          SUV
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          SUV
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          SUV
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          SUV
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline  midsize car
#
#   Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score SmartWay
# 0                   7       15      20      17                    4       no
# 1                   6       15      20      17                    4       no
# 2                   7       17      22      19                    5       no
# 3                   6       17      22      19                    5       no
# 4                   7       16      24      19                    5       no

# %%
# making the cyl column no the numberical
car08['Cyl']  = car08['Cyl'].str.extract('(\d+)').astype(int)

# %%
# replace spaces with underscores and lowercase labels for 2008 dataset
car08.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# confirm changes
car08.head(1)
# Out:
#        model  displ  cyl    trans drive      fuel veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no

# %%
car08.air_pollution_score = car08.air_pollution_score.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 car08.air_pollution_score = car08.air_pollution_score.astype(float)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
# ...
