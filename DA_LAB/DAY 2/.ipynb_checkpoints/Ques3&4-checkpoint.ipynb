# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car08= pd.read_csv('clean08.csv')
car18 = pd.read_csv('clean18.csv')

# %%
car08.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 1  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 2   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 3   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 4   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                     4
# 1                  7.0      17.0     22.0     19.0                     5
# 2                  7.0      16.0     24.0     19.0                     5
# 3                  7.0      18.0     26.0     21.0                     6
# 4                  7.0      17.0     26.0     20.0                     6
#
#   smartway
# 0       no
# 1       no
# 2       no
# 3      yes
# 4      yes

# %%
car18.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 0  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline        SUV
# 1  ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline        SUV
# 2  ACURA TLX    2.4    4       AMS-8   2WD  Gasoline  small car
# 3  ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline  small car
# 4  ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  3.0      20.0     28.0     23.0                     5
# 1                  3.0      19.0     27.0     22.0                     4
# 2                  3.0      23.0     33.0     27.0                     6
# 3                  3.0      20.0     32.0     24.0                     5
# 4                  3.0      21.0     30.0     24.0                     5
#
#   smartway
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No

# %% [markdown]
# ### Q1. Find out the alternative sources of fuel available in 2008 & 2018 respectively and by how much?

# %%
car08['fuel'].value_counts()
# Out:
# fuel
# Gasoline    984
# CNG           1
# ethanol       1
# gas           1
# Name: count, dtype: int64

# %%
car18['fuel'].value_counts()
# Out:
# fuel
# Gasoline       749
# Ethanol         26
# Gas             26
# Diesel          19
# Electricity     12
# Name: count, dtype: int64

# %%
car08['fuel'].value_counts().sum()-car08['fuel'].value_counts().max()
# Out:
# 3

# %%
car18['fuel'].value_counts().sum()-car18['fuel'].value_counts().max()
# Out:
# 83

# %% [markdown]
# ### Q2. Is there any improvement in ‘fuel economy’ with respect to vehicle class from 2008 to 2018, perform the necessary steps to examine?

# %%
car18['veh_class'].replace(['small SUV','standard SUV'],'SUV',inplace =True)

# %%
car08['veh_class'].replace('van','special purpose',inplace =True)

# %%
group08= pd.DataFrame(car08.groupby('veh_class')['cmb_mpg'].sum())
group08.rename(columns={'cmb_mpg':'cmb_mpg 08'},inplace=True)
group08
# Out:
#                  cmb_mpg 08
# veh_class
# SUV                  5172.0
# large car            1018.0
# midsize car          2981.0
# minivan               325.0
# pickup               1351.0
# small car            7028.0
# special purpose       314.0
# station wagon        1342.0

# %%
group18= pd.DataFrame(car18.groupby('veh_class')['cmb_mpg'].sum())
group18.rename(columns={'cmb_mpg':'cmb_mpg 18'},inplace=True)
group18
# Out:
#                  cmb_mpg 18
# veh_class
# SUV                  4165.0
# large car            2060.0
# midsize car          3848.0
# minivan               104.0
# pickup               1450.0
# small car            7245.0
# special purpose       185.0
# station wagon         936.0

# %%
group08['cmb_mpg_18'] = group18['cmb_mpg 18']
group08
# Out:
#                  cmb_mpg 08  cmb_mpg_18
# veh_class
# SUV                  5172.0      4165.0
# large car            1018.0      2060.0
# midsize car          2981.0      3848.0
# minivan               325.0       104.0
# pickup               1351.0      1450.0
# small car            7028.0      7245.0
# special purpose       314.0       185.0
# station wagon        1342.0       936.0

# %%
plt.figure(figsize=(15, 8))
plt.bar(group08.index, group08['cmb_mpg 08'], width=0.4, label='cmb_mpg 08')
plt.bar(group08.index, group08['cmb_mpg_18'], width=0.4, label='cmb_mpg_18', align='edge')

plt.xlabel('Vehicle Class')
plt.ylabel('Miles per Gallon (MPG)')
plt.title('MPG Comparison by Vehicle Class (2008 vs 2018)')
plt.legend()

plt.show()

# %% [markdown]
# ### Q3. Is there any change in characteristics of SmartWay Vehicles ?

# %%
# Out:
#          model      veh_class  air_pollution_score
# 3     ACURA TL    midsize car                  7.0
# 4     ACURA TL    midsize car                  7.0
# 5     ACURA TL    midsize car                  7.0
# 7    ACURA TSX      small car                  6.0
# 14     AUDI A3  station wagon                  7.0
# ..         ...            ...                  ...
# 975  VOLVO V50  station wagon                  7.0
# 976  VOLVO V50  station wagon                  7.0
# 977  VOLVO V50  station wagon                  7.0
# 978  VOLVO V50  station wagon                  7.0
# 979  VOLVO V50  station wagon                  7.0
#
# [380 rows x 3 columns]

# %%
smartway18=car18[car18['smartway']=='Yes']
smartway18[['model','veh_class','air_pollution_score']]
# Out:
#                               model    veh_class  air_pollution_score
# 15                    AUDI A4 Ultra    small car                  3.0
# 120                    BUICK Encore          SUV                  3.0
# 168                 CHEVROLET Cruze    small car                  6.0
# 169                 CHEVROLET Cruze    small car                  6.0
# 170                 CHEVROLET Cruze    small car                  3.0
# ..                              ...          ...                  ...
# 788  MINI Cooper SE Countryman All4  midsize car                  3.0
# 794                        BMW 330e    small car                  3.0
# 797                        BMW 740e    large car                  3.0
# 806                  CHEVROLET Volt    small car                  3.0
# 826  MINI Cooper SE Countryman All4  midsize car                  3.0
#
# [91 rows x 3 columns]
