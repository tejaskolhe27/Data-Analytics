# %%
import pandas as pd

# %%
election09 = pd.read_csv('LS2009Candidate.csv')
election14 = pd.read_csv('LS2014Candidate.csv')

# %%
election09['Alliance'] = election09['Party Abbreviation'].copy()
election14['Alliance'] = election14['Party Abbreviation'].copy()
election09
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 1        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 2        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 3        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 4        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8065     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8066     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8067     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8068     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8069     U07      Puducherry      3  2009          1  Puducherry     GEN
#
#               Candidate Name Candidate Sex Candidate Category  Candidate Age  \
# ...

# %%
UPA = ['INC','NCP', 'RJD', 'DMK', 'IUML','JMM','JD(s)','KC(M)','RLD','RSP'
       ,'CMP(J)','KC(J)','PPI','MD']

NDA = ['BJP','SS', 'LJP', 'SAD', 'RLSP',
'AD','PMK','NPP','AINRC','NPF','RPI(A)','BPF','JD(U)','SDF','NDPP','MNF','RIDALOS','KMDK',
       'IJK','PNK','JSP','GJM','MGP','GFP','GVP','AJSU','IPFT','MPP','KPP','JKPC','KC(T)','BDJS',
       'AGP','JSS','PPA','UDP','HSPDP','PSP','JRS','KVC','PNP','SBSP','KC(N)','PDF','MDPF']
Other = ['YSRCP','AAAP', 'IND', 'AIUDF', 'BLSP', 'JKPDP', 'JD(S)', 'INLD', 'CPI', 'AIMIM',
'KEC(M)','SWP', 'NPEP', 'JKN', 'AIFB', 'MUL', 'AUDF', 'BOPF', 'BVA', 'HJCBL',
'JVM','MDMK']

# %%
election09['Alliance'].replace(UPA,'UPA',inplace=True)
election09['Alliance'].replace(NDA,'NDA',inplace=True)
election09['Alliance'].replace(Other,'Other',inplace=True)

# %%
election14['Alliance'].replace(UPA,'UPA',inplace=True)
election14['Alliance'].replace(NDA,'NDA',inplace=True)
election14['Alliance'].replace(Other,'Other',inplace=True)

# %%
winning09 = election09.loc[election09['Position']==1.0]
winning14 = election14.loc[election14['Position']==1.0]

# %% [markdown]
# ### Q3. How many seats won by Alliances and Major Political Parties ?

# %%
# Winner seat for all the Winner Alliance in the 2009
winning09['Alliance'].value_counts()
# Out:
# Alliance
# UPA      245
# NDA      143
# Other     32
# SP        23
# BSP       21
# AITC      19
# CPM       16
# BJD       14
# SHS       11
# ADMK       9
# TDP        6
# TRS        2
# Name: count, dtype: int64

# %%
# Winner seat for all the Winner Alliance in the 2014
winning14['Alliance'].value_counts()
# Out:
# Alliance
# NDA      300
# UPA       59
# ADMK      37
# AITC      34
# Other     34
# BJD       20
# SHS       18
# TDP       16
# TRS       11
# CPM        9
# SP         5
# Name: count, dtype: int64

# %%
winning09['Party Abbreviation'].value_counts().head(10)
# Out:
# Party Abbreviation
# INC      206
# BJP      116
# SP        23
# BSP       21
# JD(U)     20
# AITC      19
# DMK       17
# CPM       16
# BJD       14
# SHS       11
# Name: count, dtype: int64

# %%
winning14['Party Abbreviation'].value_counts().head(10)
# Out:
# Party Abbreviation
# BJP      282
# INC       44
# ADMK      37
# AITC      34
# BJD       20
# SHS       18
# TDP       16
# TRS       11
# CPM        9
# YSRCP      9
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Q2 - Create Winning seats distribution by Major Political Parties & Alliances for 2009 & 2014

# %%
win09 = pd.DataFrame(winning09['Party Abbreviation'].value_counts().head(10))
win14 = pd.DataFrame(winning14['Party Abbreviation'].value_counts().head(10))

# %%
# distribution for the winning Major parties in win 2009
sns.barplot(data =win09, x= win09.index,y = 'count')
plt.show()

# %%
# distribution for the winning Major parties in win 2009
sns.barplot(data =win14, x= win14.index,y = 'count')
plt.show()

# %% [markdown]
# ### Q4 Plot comparatively seats won based on candidate category as General, ST and SC for 2009 & 2014

# %%
cat09 = pd.DataFrame(winning09['Candidate Category'].value_counts())
cat14 = pd.DataFrame(winning14['Candidate Category'].value_counts())

# %%
cat09
# Out:
#                     count
# Candidate Category
# GEN                   403
# SC                     85
# ST                     53

# %%
# pie chart for distribution inthe category of 2014
plt.pie(cat09['count'],labels=cat09.index,autopct= '%0.2f')
plt.show()

# %%
# pie chart for distribution inthe category of 2014
plt.pie(cat14['count'],labels=cat09.index,autopct= '%0.2f')
plt.show()

# %% [markdown]
# ### Q5. Plot the age distribution of winners of both 2014 and 2009 elections

# %%
#Age distribution for the candidates of 2009
sns.histplot(data = winning09,x='Candidate Age',bins =15,kde= True ,color='orange', edgecolor='red')
plt.show()

# %%
#Age distribution for the candidates of 2014
sns.histplot(data = winning14,x='Candidate Age',bins =15,kde= True ,color='orange', edgecolor='red')
plt.show()

# %% [markdown]
# ### Q6 Separately plot age distribution of NDA & UPA candidates

# %%
NDA09 = winning09.loc[winning09['Alliance']=="NDA"]
UPA09 = winning09.loc[winning09['Alliance']=="UPA"]

# %%
# distribution for the Age of UPA and NDA
sns.kdeplot(data = NDA09,x = 'Candidate Age',fill=True,label='NDA')
sns.kdeplot(data = UPA09,x = 'Candidate Age',fill=True,label='UPA')
plt.legend()
plt.show()

# %%
# distribution for the Age of UPA and NDA
NDA14 = winning14.loc[winning14['Alliance']=="NDA"]
UPA14 = winning14.loc[winning14['Alliance']=="UPA"]

# %%
sns.kdeplot(data = NDA14,x = 'Candidate Age',fill=True,label='NDA')
sns.kdeplot(data = UPA14,x = 'Candidate Age',fill=True,label='UPA')
plt.legend()
plt.legend()
plt.show()

# %% [markdown]
# ### Q7.  Plot Gender distributions of 2009 & 2014 elections

# %%
# Candidate Distribution by sex in 2009
plt.pie(election09['Candidate Sex'].value_counts(),autopct='%0.2f',labels = ['Male','Female'],startangle=90)
plt.title("Gender Distribution for 2009 Candidate")
plt.show()

# %%
# Candidate Distribution by sex in 2009
plt.pie(election14['Candidate Sex'].value_counts(),rotatelabels=45,autopct='%0.2f',labels = ['Male','Female',"Don't Know"],startangle=90)
plt.title("Gender Distribution for 2014 Candidate",pad=40)
plt.show()

# %% [markdown]
# ### 8. Plot gender distribution of NDA and UPA separately for 2009 elections
# ### 9. Plot gender distribution of NDA and UPA separately for 2014 elections

# %%
# distribution for the Age of UPA and NDA
NDA14 = election14.loc[election14['Alliance']=="NDA"]
UPA14 = election14.loc[election14['Alliance']=="UPA"]

# %%
NDA09 = election09.loc[election09['Alliance']=="NDA"]
UPA09 = election09.loc[election09['Alliance']=="UPA"]

# %%
plt.pie(NDA09['Candidate Sex'].value_counts(),autopct='%0.2f',labels = ['Male','Female'],startangle=90)
plt.title("Gender Distribution for 2009 Candidate of NDA ")
plt.show()

# %%
plt.pie(UPA09['Candidate Sex'].value_counts(),autopct='%0.2f',labels = ['Male','Female'],startangle=90)
plt.title("Gender Distribution for 2009 Candidate of UPA")
plt.show()

# %% [markdown]
# for 2014 the Gender distribution of UPA And NDA

# %%
plt.pie(NDA14['Candidate Sex'].value_counts(),autopct='%0.2f',labels = ['Male','Female'],startangle=90)
plt.title("Gender Distribution for 2014 Candidate of NDA ")
plt.show()

# %%
plt.pie(UPA14['Candidate Sex'].value_counts(),autopct='%0.2f',labels = ['Male','Female'],startangle=90)
plt.title("Gender Distribution for 2014 Candidate of UPA",pad=40)
plt.show()

# %% [markdown]
# ### 10. Plot the poll percentage of states for 2009 & 2014 elections

# %%
states = pd.DataFrame(election09.groupby('State name')['Total Votes Polled'].sum())

# %%
plt.figure(figsize=(20,16))
sns.barplot(data=states,x = states.index,y=states['Total Votes Polled'])
plt.xticks(rotation=45)
plt.show()
