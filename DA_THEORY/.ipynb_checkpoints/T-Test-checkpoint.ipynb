# %%
import numpy as np
import pandas as pd
from scipy.stats import *  #ttest,probplot
import matplotlib.pyplot as plt
import pylab
import seaborn as sns

# %%
shoes = pd.read_csv("women_shoe_prices.csv")
shoes.shape
# Out:
# /tmp/ipykernel_22143/995585915.py:1: DtypeWarning: Columns (13,16,18,22,24,32,33,40,41,47,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   shoes = pd.read_csv("women_shoe_prices.csv")
# (33801, 52)

# %%
shoes.sample(5)
# Out:
#                          id asins           brand  \
# 23530  AVpiSBcyLJeJML43kJwB   NaN  Gravity Defyer
# 11934  AVpfrDQ4ilAPnD_xgJAU   NaN   Isaac Mizrahi
# 19412  AVpgz7KtilAPnD_xxk_T   NaN        Skechers
# 26727  AVqP43_hQMlgsOJE6dmN   NaN       Aerosoles
# 27342  AVqP4763nnc1JgDc3iaC   NaN          BETANI
#
#                                               categories       colors  count  \
# 23530  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...        White    NaN
# 11934     Clothing,Shoes,Women's Shoes,All Women's Shoes         Gray    NaN
# 19412              Shoes,Sneakers,Women's Shoes,Skechers          NaN    NaN
# 26727                        Loafers,Shoes,Women's Shoes          NaN    NaN
# 27342                        Booties,Shoes,Women's Shoes  Black,Brown    NaN
#
#                   dateAdded           dateUpdated  \
# 23530  2015-09-21T12:24:04Z  2017-03-06T15:42:23Z
# 11934  2016-11-07T18:59:53Z  2016-11-07T18:59:58Z
# 19412  2016-03-27T19:01:13Z  2017-03-06T15:45:23Z
# 26727  2017-03-02T16:38:55Z  2017-03-28T11:41:38Z
# 27342  2017-03-02T16:39:11Z  2017-03-28T11:44:32Z
#
#                                             descriptions dimension  ...  \
# 23530  [{"dateSeen":["2017-03-25T09:01:25.073Z"],"sou...       NaN  ...
# 11934  [{"dateSeen":["2016-11-07T18:59:53Z"],"sourceU...       NaN  ...
# 19412  [{"dateSeen":["2017-03-25T09:18:29.428Z"],"sou...       NaN  ...
# 26727  [{"dateSeen":["2017-03-25T11:14:55.765Z"],"sou...       NaN  ...
# 27342  [{"dateSeen":["2017-03-25T14:08:29.096Z"],"sou...       NaN  ...
#
#                                                     skus  \
# 23530  [{"sourceURLs":["https://www.overstock.com/Clo...
# 11934                                                NaN
# 19412  [{"sourceURLs":["https://www.overstock.com/Clo...
# 26727  [{"sourceURLs":["https://www.overstock.com/Clo...
# 27342  [{"sourceURLs":["https://www.overstock.com/Clo...
#
#                                               sourceURLs           upc vin  \
# 23530  https://www.overstock.com/Clothing-Shoes/Women...           NaN NaN
# 11934  https://www.walmart.com/ip/Isaac-Mizrahi-Kierr...  8.895840e+11 NaN
# 19412  https://www.overstock.com/Clothing-Shoes/Women...           NaN NaN
# 26727  https://www.overstock.com/Clothing-Shoes/Women...           NaN NaN
# 27342  https://www.overstock.com/Clothing-Shoes/Betan...           NaN NaN
#
#        websiteIDs weight Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51
# 23530         NaN    NaN         NaN         NaN         NaN         NaN
# 11934         NaN    NaN         NaN         NaN         NaN         NaN
# 19412         NaN    NaN         NaN         NaN         NaN         NaN
# 26727         NaN    NaN         NaN         NaN         NaN         NaN
# 27342         NaN    NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 52 columns]

# %%
shoes['midprices'] = (shoes["prices.amountMax"]+shoes["prices.amountMin"])/2
# plot a qqplot to check normality.if the variable is normally distributed most of the point 
# should be along the central diagonal
probplot(shoes["midprices"],dist = 'norm',plot = pylab)
plt.show()

# %%
#ttest
pink = shoes[shoes.colors =='Pink']
notpink = shoes[shoes.colors !='Pink']

print(ttest_ind(pink.midprices,notpink.midprices,equal_var =False))
#there is significant price difference between pink shoes and not pink
#shoes as the p value is very small
# Out:
# TtestResult(statistic=-9.765333304558089, pvalue=9.890604434815107e-20, df=298.8638962565323)

# %%
# something else now
plt.hist(shoes.midprices)
plt.show()

# %%
#lets see if there is a differnce if we limit to the price of the shoe to under 300
shoesreduced = shoes[shoes.midprices<300]
entries_removed = shoes.shape[0]-shoesreduced.shape[0]
print("Removed shoes that are under 300 : ",entries_removed)
# Out:
# Removed shoes that are under 300 :  1129

# %%
shoes = shoes[shoes.midprices<300] # removed the shoes under 300
plt.hist(shoes.midprices)
plt.show()

# %%
shoes.shape
# Out:
# (32672, 53)

# %%
probplot(shoes.midprices,dist = 'norm',plot = pylab)
plt.show()

# %%
#ttest
pink = shoes[shoes.colors =='Pink']
notpink = shoes[shoes.colors !='Pink']

print(ttest_ind(pink.midprices,notpink.midprices,equal_var =False))
#there is significant price difference between pink shoes and not pink
#shoes as the p value is very small
# Out:
# TtestResult(statistic=-6.536695383829033, pvalue=3.0484470604648535e-10, df=274.7558747857281)
