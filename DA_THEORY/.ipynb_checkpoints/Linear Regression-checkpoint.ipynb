# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# Step 1: Load Data

# %%
dataset = pd.read_csv('salary.csv')

# for X(independent variable), take all the columns from the file, except salary
X = dataset.iloc[:,:-1].values
# For y(independent variable)
y = dataset.iloc[:,1].values

# %% [markdown]
# Step 2: Split data into training and testing

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=0)

# %% [markdown]
# Step 3: Fit Simple Linear regression to training data

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Step 4: Make Prediction

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %% [markdown]
# Step 5: Visualize training set results

# %%
plt.scatter(X_train,y_train,color='red')
#plot the regression line
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary vs Experience(Training Set)")
plt.show()

# %% [markdown]
# Step 6: Visualize test set result

# %%
plt.scatter(X_test,y_test,color='red')
#plot the regression line
plt.plot(X_test,regressor.predict(X_test),color='blue')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary vs Experience(Testing Set)")
plt.show()

# %% [markdown]
# Step 7: Make new prediction

# %%
new_salary_pred = regressor.predict([[15]])
print("The predicted salary of a person with 15yrs of experience: ",new_salary_pred)
# Out:
# The predicted salary of a person with 15yrs of experience:  [166468.72605157]

# %% [markdown]
# ACCURACY OF MODEL

# %%
import sklearn.metrics as sm
print("R2 score =", round(sm.r2_score(y_test, y_pred), 2))
# Out:
# R2 score = 0.99
