# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marketing=pd.read_csv("marketing.csv")

# %%
plt.boxplot(marketing['Income'])
plt.show()

# %%
marketing["Income"].max()
# Out:
# 162397

# %%
q1,q3=np.percentile(marketing['Income'],[25,75])
q1
# Out:
# 35284.0
